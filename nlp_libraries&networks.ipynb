# %%
# Question 6 :-Write a Python program using TextBlob to perform sentiment analysis on the paragraph and print polarity and subjectivity scores.
from textblob import TextBlob

text = """I had a great experience using the new mobile banking app.
The interface is intuitive, and customer support was quick to resolve my issue.
However, the app did crash once during a transaction, which was frustrating."""

blob = TextBlob(text)

print("Polarity:", blob.sentiment.polarity)
print("Subjectivity:", blob.sentiment.subjectivity)
# Out:
# Polarity: 0.21742424242424244
# Subjectivity: 0.6511363636363636

# %%
# Question 7 :- Perform string tokenization and frequency distribution using Python and NLTK for the given paragraph.
import nltk
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist

text = """Natural Language Processing (NLP) is a fascinating field that combines
linguistics, computer science, and artificial intelligence. It enables machines
to understand, interpret, and generate human language."""

tokens = word_tokenize(text)

fdist = FreqDist(tokens)

print("Tokens:")
print(tokens)

print("\nFrequency Distribution:")
print(fdist.most_common(10))
# Out:
# Tokens:
# ['Natural', 'Language', 'Processing', '(', 'NLP', ')', 'is', 'a', 'fascinating', 'field', 'that', 'combines', 'linguistics', ',', 'computer', 'science', ',', 'and', 'artificial', 'intelligence', '.', 'It', 'enables', 'machines', 'to', 'understand', ',', 'interpret', ',', 'and', 'generate', 'human', 'language', '.']
#
# Frequency Distribution:
# [(',', 4), ('and', 2), ('.', 2), ('Natural', 1), ('Language', 1), ('Processing', 1), ('(', 1), ('NLP', 1), (')', 1), ('is', 1)]

# %%
#Question 8: Implement a basic LSTM model in Keras for text classification using the given dataset.
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

texts = [
"I love this project",
"This is an amazing experience",
"I hate waiting in line",
"This is the worst service",
"Absolutely fantastic!"
]

labels = [1,1,0,0,1]
labels = np.array(labels)   

tokenizer = Tokenizer()
tokenizer.fit_on_texts(texts)

sequences = tokenizer.texts_to_sequences(texts)
padded = pad_sequences(sequences, maxlen=5)

model = Sequential()
model.add(Embedding(input_dim=50, output_dim=8))
model.add(LSTM(16))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.fit(padded, labels, epochs=10)

print("Model training completed")
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 0.6905
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8000 - loss: 0.6895
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6000 - loss: 0.6884
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6000 - loss: 0.6874
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6000 - loss: 0.6863
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6000 - loss: 0.6852
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6000 - loss: 0.6840
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6000 - loss: 0.6828
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6000 - loss: 0.6816
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6000 - loss: 0.6803
# Model training completed

# %%
#Question 9: Using spaCy, build an NLP pipeline that performs tokenization, lemmatization, and named entity recognition.
import spacy

nlp = spacy.load("en_core_web_sm")

text = """Homi Jehangir Bhabha was an Indian nuclear physicist who played a key role
in the development of India’s atomic energy program."""

doc = nlp(text)

print("Tokens and Lemmas:")
for token in doc:
    print(token.text, "->", token.lemma_)

print("\nNamed Entities:")
for ent in doc.ents:
    print(ent.text, "-", ent.label_)
# Out:
# Tokens and Lemmas:
# Homi -> Homi
# Jehangir -> Jehangir
# Bhabha -> Bhabha
# was -> be
# an -> an
# Indian -> indian
# nuclear -> nuclear
# physicist -> physicist
# who -> who
# played -> play
# a -> a
# key -> key
# role -> role
#
#  ->
#
# in -> in
# the -> the
# development -> development
# of -> of
# India -> India
# ’s -> ’s
# atomic -> atomic
# energy -> energy
# program -> program
# . -> .
#
# Named Entities:
# Homi Jehangir Bhabha - PERSON
# Indian - NORP
# India - GPE

# %%
# Question 10
# Explain how LSTM or GRU networks with spaCy or Stanford NLP can be used to build a chatbot for a mental health platform.

# Answer
# A mental health chatbot can use spaCy or Stanford NLP for text preprocessing tasks such as tokenization, lemmatization, and entity recognition. The processed text is then passed to an LSTM or GRU neural network, which understands the sequence of words and predicts the user's intent. The architecture includes an input layer, embedding layer, LSTM/GRU layer, and a dense output layer for response prediction. The chatbot can then generate helpful responses using predefined templates or a response generation model. Ethical considerations include maintaining user privacy, avoiding harmful advice, and ensuring the chatbot encourages users to seek professional help when necessary.
